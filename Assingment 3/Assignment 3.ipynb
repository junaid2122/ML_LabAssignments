# %% [markdown]
# # Assignment 3

# %% [markdown]
# **Visualize the data using R/Python by plotting the graphs for assignment no. 1 and 2. Consider
# suitable data set. Use Scatter plot, Bar plot, Box plot, Pie chart, Line Chart.t**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('Customers - Customers.csv')
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID                 0
# Gender                     0
# Age                        0
# Annual Income ($)          0
# Spending Score (1-100)     0
# Profession                35
# Work Experience            0
# Family Size                0
# dtype: int64

# %%
df.nunique()
# Out:
# CustomerID                2000
# Gender                       2
# Age                        100
# Annual Income ($)         1786
# Spending Score (1-100)     101
# Profession                   9
# Work Experience             18
# Family Size                  9
# dtype: int64

# %%
sns.pairplot(data= df, kind="reg")
plt.show()

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income ($)',
#        'Spending Score (1-100)', 'Profession', 'Work Experience',
#        'Family Size'],
#       dtype='object')

# %%
plt.hist(data=df,x="Annual Income ($)",y="Age")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/axis.py:1813, in Axis.convert_units(self, x)
#    1812 try:
# -> 1813     ret = self.converter.convert(x, self.units, self)
#    1814 except Exception as e:
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# ...

# %%
sns.barplot(data=df,x="Annual Income ($)",y="Age",)
plt.show()

# %%
plt.pie(data=df,x="Profession",labels=df["Profession"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.pie(data=df,x="Profession",labels=df["Profession"])
#       2 plt.show()
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:3762, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3739 @_copy_docstring_and_deprecators(Axes.pie)
#    3740 def pie(
#    3741     x: ArrayLike,
#    (...)
#    3760     data=None,
#    3761 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3762     return gca().pie(
#    3763         x,
#    3764         explode=explode,
#    3765         labels=labels,
#    3766         colors=colors,
#    3767         autopct=autopct,
#    3768         pctdistance=pctdistance,
# ...

# %%
plt.figure(figsize = (20,20))
sns.catplot(data=df,kind= "bar",x="Profession",y="Age",hue="Gender")
plt.show()

# %%
sns.displot(data=df,x="Annual Income ($)",hue="Gender")

# %%
# Set style
sns.set(style="whitegrid")

# %%
# Create subplots
fig, axes = plt.subplots(3, 2, figsize=(15, 15))
fig.suptitle("Data Visualizations", fontsize=16)


# Scatter Plot: Age vs. Spending Score
sns.scatterplot(x=df["Age"], y=df["Spending Score (1-100)"], hue=df["Gender"], alpha=0.6, ax=axes[0, 0])
axes[0, 0].set_title("Scatter Plot: Age vs. Spending Score")

# Bar Plot: Average Annual Income by Profession
avg_income = df.groupby("Profession")["Annual Income ($)"].mean().sort_values()
avg_income.dropna().plot(kind="barh", ax=axes[0, 1], color="skyblue")
axes[0, 1].set_title("Bar Plot: Average Annual Income by Profession")

# Box Plot: Distribution of Annual Income
sns.boxplot(y=df["Annual Income ($)"], ax=axes[1, 0], color="lightcoral")
axes[1, 0].set_title("Box Plot: Distribution of Annual Income")

# Pie Chart: Distribution of Genders
gender_counts = df["Gender"].value_counts()
axes[1, 1].pie(gender_counts, labels=gender_counts.index, autopct="%1.1f%%", colors=["lightblue", "pink"])
axes[1, 1].set_title("Pie Chart: Gender Distribution")

# Line Chart: Age vs. Spending Score Trend
df_sorted = df.sort_values("Age")
sns.lineplot(x=df_sorted["Age"], y=df_sorted["Spending Score (1-100)"], ax=axes[2, 0], color="purple")
axes[2, 0].set_title("Line Chart: Age vs. Spending Score")

# Hide the last empty subplot
axes[2, 1].axis("off")

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
